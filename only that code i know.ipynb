# %% [markdown]
# <a href="https://colab.research.google.com/github/Bantyrajpuana/python-tutorial/blob/main/only%20that%20code%20i%20know.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello are you starting your first journey :::  lets go on ")
# Out:
# hello are you starting your first journey :::  lets go on

# %%
B='B'
A='A'
N='N'
T='T'
Y='Y'


print ("ASCII VALUE IS :",ord(B))
print ("ASCII VALUE IS :",ord(A))
print ("ASCII VALUE IS :",ord(N))
print ("ASCII VALUE IS :",ord(T))
print ("ASCII VALUE IS :",ord(Y))
# Out:
# ASCII VALUE IS : 66
# ASCII VALUE IS : 65
# ASCII VALUE IS : 78
# ASCII VALUE IS : 84
# ASCII VALUE IS : 89

# %%
#create calculater
def add(a,b):
    return a+b
    def sub(a,b):
        return a-b
        def mul(a,b):
            return a*b
            def div(a,b):
                return a/b
                def mod(a,b):
                    return a%b
                    def power(a,b):
                        return a**b
                        def floor(a,b):
                            return a//b
                            def square(a,b):
                                return a**2
                                def cube(a,b):
                                    return a**3
                                    def square_root(a,b):
                                        return a**0.5
                                        def cube_root(a,b):
                                            return a**0.33
                                            def log(a,b):
                                                return a**0.1
                                                def log10(a,b):
                                                    return a**0.01
                                                    def log2(a,b):
                                                        return a**0.00



                                                    print("select operation")
                                                    print("1.add")
                                                    print("2.sub")
                                                    print("3.mul")
                                                    print("4.div")
                                                    print("5.mod")
                                                    print("6.power")
                                                    print("7.floor")
                                                    print("8.square")
                                                    print("9.cube")
                                                    print("10.square_root")
                                                    print("11.cube_root")
                                                    print("12.log")
                                                    print("13.log10")
                                                    print("14.log2")



while True:
   choice=input("enter your choice (1-14)")

if choice in ('1','2','3','4','5','6','7'):
    try:
        num1=float(input("enter first number"))
        num2=float(input("enter second number"))
    except ValueError:
        print("invalid input")
        continue

        if choice=='1':
            print(num1,"+",num2,"=",add(num1,num2))
        elif choice=='2':
                print(num1,"-",num2,"=",sub(num1,num2))
        elif choice=='3':
                    print(num1,"*",num2,"=",mul(num1,num2))
        elif choice=='4':
                        print(num1,"/",num2,"=",div(num1,num2))
        elif choice=='5':
                             print(num1,"%",num2,"=",mod(num1,num2))
        elif choice=='6':
                               print(num1,"**",num2,"=",power(num1,num2))
        elif choice=='7':
                                 print(num1,"//",num2,"=",floor(num1,num2))

elif choice in('8','9','10','11','12','13','14'):
    try:
        num1=float(input("enter first number"))
    except ValueError:
        print("invalid input")
        continue

        if choice=='8':
                                    print(num1,"**",2,"=",square(num1,num2))
        elif choice=='9':
                                     print(num1,"**",3,"=",cube(num1,num2))
        elif choice=='10':
                                       print(num1,"**",0.5,"=",square_root(num1,num2))
        elif choice=='11':
                                         print(num1,"**",0.33,"=",cube_root(num1,num2))
        elif choice=='12':
                                          print(num1,"**",0.1,"=",log(num1,num2))
        elif choice=='13':
                                           print(num1,"**",0.01,"=",log10(num1,num2))
        elif choice=='14':
                                            print(num1,"**",0.00,"=",log2(num1,num2))
    else:
        print("invalid input")

        next_calculation = input("Do you want to perform another calculation? (yes/no): ").lower()
    if next_calculation == "no":
        break
    else:
        continue

# %%
# Define calculator functions
def add(a, b):
    return a + b

def sub(a, b):
    return a - b

def mul(a, b):
    return a * b

def div(a, b):
    if b != 0:
        return a / b
    else:
        return "Division by zero is not allowed"

def mod(a, b):
    return a % b

def power(a, b):
    return a ** b

def floor(a, b):
    if b != 0:
        return a // b
    else:
        return "Division by zero is not allowed"

def square(a):
    return a ** 2

def cube(a):
    return a ** 3

def square_root(a):
    return a ** 0.5

def cube_root(a):
    return a ** (1 / 3)

def log(a):
    return a ** 0.1

def log10(a):
    return a ** 0.01

def log2(a):
    return a ** 0.00

# Menu for calculator
print("Select operation:")
print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")
print("5. Modulus")
print("6. Power")
print("7. Floor Division")
print("8. Square")
print("9. Cube")
print("10. Square Root")
print("11. Cube Root")
print("12. Log")
print("13. Log10")
print("14. Log2")

while True:
    # Take user input
    choice = input("Enter your choice (1-14): ")

    if choice in ('1', '2', '3', '4', '5', '6', '7'):
        try:
            num1 = float(input("Enter the first number: "))
            num2 = float(input("Enter the second number: "))
        except ValueError:
            print("Invalid input. Please enter numeric values.")
            continue

        if choice == '1':
            print(num1, "+", num2, "=", add(num1, num2))
        elif choice == '2':
            print(num1, "-", num2, "=", sub(num1, num2))
        elif choice == '3':
            print(num1, "*", num2, "=", mul(num1, num2))
        elif choice == '4':
            print(num1, "/", num2, "=", div(num1, num2))
        elif choice == '5':
            print(num1, "%", num2, "=", mod(num1, num2))
        elif choice == '6':
            print(num1, "**", num2, "=", power(num1, num2))
        elif choice == '7':
            print(num1, "//", num2, "=", floor(num1, num2))
    elif choice in ('8', '9', '10', '11', '12', '13', '14'):
        try:
            num = float(input("Enter the number: "))
        except ValueError:
            print("Invalid input. Please enter numeric values.")
            continue

        if choice == '8':
            print(num, "** 2 =", square(num))
        elif choice == '9':
            print(num, "** 3 =", cube(num))
        elif choice == '10':
            print(num, "** 0.5 =", square_root(num))
        elif choice == '11':
            print(num, "** (1/3) =", cube_root(num))
        elif choice == '12':
            print(num, "** 0.1 =", log(num))
        elif choice == '13':
            print(num, "** 0.01 =", log10(num))
        elif choice == '14':
            print(num, "** 0.00 =", log2(num))

    else:
        print("Invalid input. Please choose a valid option.")

    # Check if the user wants another calculation
    next_calculation = input("Do you want to perform another calculation? (yes/no): ").lower()
    if next_calculation == "no":
        break
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# 5. Modulus
# 6. Power
# 7. Floor Division
# 8. Square
# 9. Cube
# 10. Square Root
# 11. Cube Root
# 12. Log
# 13. Log10
# 14. Log2

# %%
dashes=int(input("how many dashes u want = "))
print("-"*dashes)
# Out:
# how many dashes u want = 666
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
text=('banty is god')
print(text.upper())
print(text.lower())
print(text.title())
# Out:
# BANTY IS GOD
# banty is god
# <built-in method title of str object at 0x7aba5ceb1b70>

# %%
x=float(input("enter first number"))
y=float(input("enter second number"))
z=float(input("enter third number"))
(x,y,z)=(z,x,y)
print(f"{x} first one {y} second  {z} third")
# Out:
# enter first number45
# enter second number23
# enter third number11
# 11.0 first one 45.0 second  23.0 third

# %%
#  POSITIVE, NEGATIVE OR ZERO

num=float(input("enter a number  =  "))
if num>0:
    print("positive number")
elif num==0:
    print("zero")
else:
    print("negative number")
# Out:
# enter a number  =  -88
# negative number

# %%
# CHEACK LEAP YEAR
import random
year = random.randint(1000,9999)
def CHEACK_LEAP_YEAR(year):
    if (year%4==0 and year%100!=0) or (year%400==0):
        return True
    else:
        return False
print(year)
print(CHEACK_LEAP_YEAR(year))
# Out:
# 4912
# True

# %%
import random
banty = random.randint(1,100)
print(banty)
# Out:
# 60

# %%
#factorial no
def factorial(n):
  if n==0:
   return 1
  else:
    return n*factorial(n-1)
n = int(input("enter factorial = "))
print (factorial(n))
# Out:
# enter factorial = 66
# 544344939077443064003729240247842752644293064388798874532860126869671081148416000000000000000
# 66

# %%
#check prime
def is_prime(n):
    if n<=1:
      return False
    for i in range(2,int(n**0.5)+1):

        if n%i==0:
            return False
    return True
n = int(input("enter number = "))
print(is_prime(n))
# Out:
# enter number = 536566476783
# False

# %%
#prime interval
lower = int(input("enter lower number = "))
upper = int(input("enter upper number = "))
for num in range (lower,upper+1):
   if num > 1:
    for i in range (2,num+1):
       if (num%i)==0:
           break
       else:
          print(num)
# Out:
# Streaming output truncated to the last 5000 lines.
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# 229
# ...
